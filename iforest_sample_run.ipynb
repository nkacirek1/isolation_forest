# %%
import pandas as pd
from plot_anomalies import plot_anomalies

# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')
N = 20_000
df = df.sample(N)  # grab random subset (too slow otherwise)

# %%
df.Class.value_counts()
# Out:
# 0    19969
# 1       31
# Name: Class, dtype: int64

# %%
X, y = df.drop('Class', axis=1), df['Class']

# %% [markdown]
# ## Using Plot Anomalies

# %%
plot_anomalies(X, y, sample_size=256, n_trees=200, desired_TPR=0.8, bins=15)
# Out:
# fit time 0.27s
# score time 26.67s
# Computed 0.8000 TPR threshold 0.4850 with FPR 0.0426
# [[19118   851]
#  [    6    25]]
# Proportion anomalies/normal = 31/19969 = 0.2%
# F1 score 0.0551, avg PR 0.1294

# %%
plot_anomalies(X, y, sample_size=256, n_trees=200, desired_TPR=0.9, bins=15)
# Out:
# fit time 0.26s
# score time 28.30s
# Computed 0.9000 TPR threshold 0.4300 with FPR 0.1892
# [[16191  3778]
#  [    3    28]]
# Proportion anomalies/normal = 31/19969 = 0.2%
# F1 score 0.0146, avg PR 0.1964
